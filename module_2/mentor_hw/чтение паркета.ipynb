# %%
import pandas as pd

# %%
pd.read_parquet('part-00000-1b517703-cb36-4996-8910-8b544b4f5935-c000.snappy.parquet')
# Out:
#       city product_id  product_name  orders_cnt  qty_sum  revenue_sum
# 0   Berlin         p3  Ring TISHINA           1        5         35.0
# 1   Berlin         p1     Ring VOLA           2        3         30.0
# 2  Hamburg         p1     Ring VOLA           1       10        100.0
# 3   Munich         p2    Ring POROG           1        3         90.0
# 4   Munich         p3  Ring TISHINA           1        1          7.0
